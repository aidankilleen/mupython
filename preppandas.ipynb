# %%
import pandas as pd

df = pd.read_csv("Pandas - Q1 Sales.csv")

df.head()
# Out:
#      Country Region Sales Person    Date of Purchase   Total  Quantity
# 0      India  North         John   1/27/2013 0:00:00  100000       567
# 1         US  North         Bill  10/25/2018 0:00:00  120000      3000
# 2         UK  North       Thomas   4/29/2014 0:00:00  140000       345
# 3  Australia   East         John    6/3/2011 0:00:00  160000      1000
# 4     Africa   East         Bill   8/27/2014 0:00:00  180000       123

# %%
df.describe()
# Out:
#               Total     Quantity
# count  2.000000e+01    20.000000
# mean   1.502500e+06   977.900000
# std    5.769280e+06  1761.923497
# min    1.000000e+05    85.000000
# 25%    1.400000e+05    90.000000
# 50%    1.700000e+05   505.500000
# 75%    2.250000e+05  1000.000000
# max    2.600000e+07  7890.000000

# %%
df.columns.values
# Out:
# array(['Country', 'Region', 'Sales Person', 'Date of Purchase', 'Total',
#        'Quantity'], dtype=object)

# %%
dfs = pd.read_html("https://en.wikipedia.org/wiki/List_of_Irish_counties_by_population")

print (dfs)

df = dfs[0]

print (df)
# Out:
# [     Rank                  County  Population  Density (km²)  \
# 0       1                  Dublin     1345402         1459.2
# 1       2                  Antrim      618108          202.9
# 2       3                    Cork      542868           72.3
# 3       4                    Down      531665          215.6
# 4       –                  Fingal      296020          651.6
# 5       –            South Dublin      278767         1251.5
# 6       5                  Galway      258058           42.0
# 7       6             Londonderry      247132          119.1
# 8       7                 Kildare      222504          131.0
# 9       –  Dún Laoghaire–Rathdown      218018         1706.7
# 10      8                   Meath      195044           83.2
# 11      9                Limerick      194899           70.8
# 12     10                  Tyrone      179000           54.5
# 13     11                  Armagh      174792          131.8
# ...

# %%
dfss = pd.read_html("https://en.wikipedia.org/wiki/Demographics_of_the_Republic_of_Ireland")

print (len(dfss))

for table in dfss:
    print(table.head())
# Out:
# 19
#              Demographics of the Republic of Ireland  \
# 0  Population pyramid of the Republic of Ireland ...
# 1                                         Population
# 2                                            Density
# 3                                        Growth rate
# 4                                         Birth rate
#
#            Demographics of the Republic of Ireland.1
# 0  Population pyramid of the Republic of Ireland ...
# 1                            4,761,865 (2016 census)
# 2                                         68 per km2
# 3                                              1.77%
# 4                       13.7 births/1,000 population
#    Year     Pop.      ±%
# 0  1841  6528799       —
# 1  1851  5111557  −21.7%
# 2  1861  4402111  −13.9%
# 3  1871  4053187   −7.9%
# 4  1881  3870020   −4.5%
#     0                                                  1
# 0 NaN  This section needs to be updated. Please help ...
#   Nationality Group 2002[13]          2006[13]
# ...

# %%
subset = df.iloc[:, 1:4].copy()

print (subset)

ax = df.plot.bar(x='County', y='Population', rot=0)
# Out:
#                     County  Population  Density (km²)
# 0                   Dublin     1345402         1459.2
# 1                   Antrim      618108          202.9
# 2                     Cork      542868           72.3
# 3                     Down      531665          215.6
# 4                   Fingal      296020          651.6
# 5             South Dublin      278767         1251.5
# 6                   Galway      258058           42.0
# 7              Londonderry      247132          119.1
# 8                  Kildare      222504          131.0
# 9   Dún Laoghaire–Rathdown      218018         1706.7
# 10                   Meath      195044           83.2
# 11                Limerick      194899           70.8
# 12                  Tyrone      179000           54.5
# 13                  Armagh      174792          131.8
# 14               Tipperary      159553           37.2
# 15                 Donegal      159192           32.6
# ...

# %%
import matplotlib.pyplot as plt

f = plt.figure()
plt.title("Population By County")
df.plot(ax=)
